# %%
import pandas as pd

# %%
df_A = pd.read_csv(r'Dataframes\df_employees.csv')
df_B = pd.read_csv(r'Dataframes\df_emp_details.csv')

# %%
df_A.head()
# Out:
#   Emp_ID Dept_ID     Name  Age  Salary
# 0   E001    D001    Alice   49   69779
# 1   E002    D002      Bob   41   62247
# 2   E003    D004  Charlie   30   53546
# 3   E004    D001    David   46   43066
# 4   E005    D002   Evelyn   32   42264

# %%
print("DF Employees:\n", df_A.head(), "\n")
print("DF Employee Details:\n", df_B.head())
# Out:
# DF Employees:
#    Emp_ID Dept_ID     Name  Age  Salary
# 0   E001    D001    Alice   49   69779
# 1   E002    D002      Bob   41   62247
# 2   E003    D004  Charlie   30   53546
# 3   E004    D001    David   46   43066
# 4   E005    D002   Evelyn   32   42264
#
# DF Employee Details:
#    Emp_ID Dept_ID Location  Experience  Bonus
# 0   E010    D002   Sydney           3   9574
# 1   E011    D002    Tokyo          12   6596
# 2   E012    D001    Tokyo           2   8977
# 3   E013    D005   London           7   8311
# 4   E014    D002    Tokyo          10   4509

# %%
print("df1 is unique?: ",df_A['Emp_ID'].is_unique)
print("df2 is unique?: ",df_B['Emp_ID'].is_unique)
# Out:
# df1 is unique?:  True
# df2 is unique?:  True

# %% [markdown]
# ### 01 - Merging

# %% [markdown]
# 1.1 - Merging using one key

# %%
merged_one = pd.merge(df_A, df_B, on='Emp_ID')
merged_one
# Out:
#    Emp_ID Dept_ID_x   Name  Age  Salary Dept_ID_y  Location  Experience  Bonus
# 0    E010      D002   Jane   47   79140      D002    Sydney           3   9574
# 1    E011      D003   Karl   39   47488      D002     Tokyo          12   6596
# 2    E012      D003   Lina   42   86429      D001     Tokyo           2   8977
# 3    E013      D001   Mike   37   46319      D005    London           7   8311
# 4    E014      D004   Nina   42   51768      D002     Tokyo          10   4509
# 5    E015      D003   Owen   30   55434      D005    Sydney          11   7031
# 6    E016      D001   Paul   33   68002      D005     Tokyo           5   9622
# 7    E017      D004  Queen   34   85616      D001    Sydney          14   7836
# 8    E018      D003   Rita   25   59459      D001    Sydney           7   2649
# 9    E019      D003  Steve   42   79202      D005     Tokyo          14   5529
# 10   E020      D004   Tina   47   44057      D005  New York          14   3069

# %% [markdown]
# 1.2 - using multiple keys

# %%
merged_multi = pd.merge(df_A, df_B, on=['Emp_ID', 'Dept_ID'])
merged_multi
# Out:
#   Emp_ID Dept_ID  Name  Age  Salary Location  Experience  Bonus
# 0   E010    D002  Jane   47   79140   Sydney           3   9574

# %% [markdown]
# 1.3 - Using how argument

# %%
df_A
# Out:
#    Emp_ID Dept_ID     Name  Age  Salary
# 0    E001    D001    Alice   49   69779
# 1    E002    D002      Bob   41   62247
# 2    E003    D004  Charlie   30   53546
# 3    E004    D001    David   46   43066
# 4    E005    D002   Evelyn   32   42264
# 5    E006    D001    Frank   47   79051
# 6    E007    D004    Grace   31   51542
# 7    E008    D002    Helen   31   72880
# 8    E009    D001      Ian   26   68708
# 9    E010    D002     Jane   47   79140
# 10   E011    D003     Karl   39   47488
# 11   E012    D003     Lina   42   86429
# 12   E013    D001     Mike   37   46319
# 13   E014    D004     Nina   42   51768
# 14   E015    D003     Owen   30   55434
# 15   E016    D001     Paul   33   68002
# 16   E017    D004    Queen   34   85616
# 17   E018    D003     Rita   25   59459
# 18   E019    D003    Steve   42   79202
# 19   E020    D004     Tina   47   44057

# %%
df_B
# Out:
#    Emp_ID Dept_ID  Location  Experience  Bonus
# 0    E010    D002    Sydney           3   9574
# 1    E011    D002     Tokyo          12   6596
# 2    E012    D001     Tokyo           2   8977
# 3    E013    D005    London           7   8311
# 4    E014    D002     Tokyo          10   4509
# 5    E015    D005    Sydney          11   7031
# 6    E016    D005     Tokyo           5   9622
# 7    E017    D001    Sydney          14   7836
# 8    E018    D001    Sydney           7   2649
# 9    E019    D005     Tokyo          14   5529
# 10   E020    D005  New York          14   3069
# 11   E021    D005    Sydney           3   3329
# 12   E022    D005     Tokyo          13   5212
# 13   E023    D001    Sydney           9   6977
# 14   E024    D005  New York           3   9638
# 15   E025    D001  New York           2   8783
# 16   E026    D005     Tokyo          10   8214
# 17   E027    D001  New York           1   5636
# 18   E028    D005     Tokyo          11   8348
# 19   E029    D002    Sydney          10   4009

# %%
# Inner join
inner_merge = pd.merge(df_A, df_B, on='Emp_ID', how='inner')
print("Inner join:",inner_merge.shape)
# Out:
# Inner join: (11, 9)

# %%
inner_merge
# Out:
#    Emp_ID Dept_ID_x   Name  Age  Salary Dept_ID_y  Location  Experience  Bonus
# 0    E010      D002   Jane   47   79140      D002    Sydney           3   9574
# 1    E011      D003   Karl   39   47488      D002     Tokyo          12   6596
# 2    E012      D003   Lina   42   86429      D001     Tokyo           2   8977
# 3    E013      D001   Mike   37   46319      D005    London           7   8311
# 4    E014      D004   Nina   42   51768      D002     Tokyo          10   4509
# 5    E015      D003   Owen   30   55434      D005    Sydney          11   7031
# 6    E016      D001   Paul   33   68002      D005     Tokyo           5   9622
# 7    E017      D004  Queen   34   85616      D001    Sydney          14   7836
# 8    E018      D003   Rita   25   59459      D001    Sydney           7   2649
# 9    E019      D003  Steve   42   79202      D005     Tokyo          14   5529
# 10   E020      D004   Tina   47   44057      D005  New York          14   3069

# %%
# Left join
left_merge = pd.merge(df_A, df_B, on='Emp_ID', how='left')
print("Left join:",left_merge.shape)
# Out:
# Left join: (20, 9)

# %%
left_merge
# Out:
#    Emp_ID Dept_ID_x     Name  Age  Salary Dept_ID_y  Location  Experience  \
# 0    E001      D001    Alice   49   69779       NaN       NaN         NaN
# 1    E002      D002      Bob   41   62247       NaN       NaN         NaN
# 2    E003      D004  Charlie   30   53546       NaN       NaN         NaN
# 3    E004      D001    David   46   43066       NaN       NaN         NaN
# 4    E005      D002   Evelyn   32   42264       NaN       NaN         NaN
# 5    E006      D001    Frank   47   79051       NaN       NaN         NaN
# 6    E007      D004    Grace   31   51542       NaN       NaN         NaN
# 7    E008      D002    Helen   31   72880       NaN       NaN         NaN
# 8    E009      D001      Ian   26   68708       NaN       NaN         NaN
# 9    E010      D002     Jane   47   79140      D002    Sydney         3.0
# 10   E011      D003     Karl   39   47488      D002     Tokyo        12.0
# 11   E012      D003     Lina   42   86429      D001     Tokyo         2.0
# 12   E013      D001     Mike   37   46319      D005    London         7.0
# 13   E014      D004     Nina   42   51768      D002     Tokyo        10.0
# 14   E015      D003     Owen   30   55434      D005    Sydney        11.0
# 15   E016      D001     Paul   33   68002      D005     Tokyo         5.0
# 16   E017      D004    Queen   34   85616      D001    Sydney        14.0
# 17   E018      D003     Rita   25   59459      D001    Sydney         7.0
# 18   E019      D003    Steve   42   79202      D005     Tokyo        14.0
# 19   E020      D004     Tina   47   44057      D005  New York        14.0
#
#      Bonus
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9   9574.0
# 10  6596.0
# 11  8977.0
# 12  8311.0
# 13  4509.0
# 14  7031.0
# 15  9622.0
# 16  7836.0
# 17  2649.0
# 18  5529.0
# 19  3069.0

# %%
# Right join
right_merge = pd.merge(df_A, df_B, on='Emp_ID', how='right')
print("Right join:",right_merge.shape)
# Out:
# Right join: (20, 9)

# %%
right_merge
# Out:
#    Emp_ID Dept_ID_x   Name   Age   Salary Dept_ID_y  Location  Experience  \
# 0    E010      D002   Jane  47.0  79140.0      D002    Sydney           3
# 1    E011      D003   Karl  39.0  47488.0      D002     Tokyo          12
# 2    E012      D003   Lina  42.0  86429.0      D001     Tokyo           2
# 3    E013      D001   Mike  37.0  46319.0      D005    London           7
# 4    E014      D004   Nina  42.0  51768.0      D002     Tokyo          10
# 5    E015      D003   Owen  30.0  55434.0      D005    Sydney          11
# 6    E016      D001   Paul  33.0  68002.0      D005     Tokyo           5
# 7    E017      D004  Queen  34.0  85616.0      D001    Sydney          14
# 8    E018      D003   Rita  25.0  59459.0      D001    Sydney           7
# 9    E019      D003  Steve  42.0  79202.0      D005     Tokyo          14
# 10   E020      D004   Tina  47.0  44057.0      D005  New York          14
# 11   E021       NaN    NaN   NaN      NaN      D005    Sydney           3
# 12   E022       NaN    NaN   NaN      NaN      D005     Tokyo          13
# 13   E023       NaN    NaN   NaN      NaN      D001    Sydney           9
# 14   E024       NaN    NaN   NaN      NaN      D005  New York           3
# 15   E025       NaN    NaN   NaN      NaN      D001  New York           2
# 16   E026       NaN    NaN   NaN      NaN      D005     Tokyo          10
# 17   E027       NaN    NaN   NaN      NaN      D001  New York           1
# 18   E028       NaN    NaN   NaN      NaN      D005     Tokyo          11
# 19   E029       NaN    NaN   NaN      NaN      D002    Sydney          10
#
#     Bonus
# 0    9574
# 1    6596
# 2    8977
# 3    8311
# 4    4509
# 5    7031
# 6    9622
# 7    7836
# 8    2649
# 9    5529
# 10   3069
# 11   3329
# 12   5212
# 13   6977
# 14   9638
# 15   8783
# 16   8214
# 17   5636
# 18   8348
# 19   4009

# %%
# Outer join
outer_merge = pd.merge(df_A, df_B, on='Emp_ID', how='outer')
print("Outer join:",outer_merge.shape)
# Out:
# Outer join: (29, 9)

# %%
outer_merge
# Out:
#    Emp_ID Dept_ID_x     Name   Age   Salary Dept_ID_y  Location  Experience  \
# 0    E001      D001    Alice  49.0  69779.0       NaN       NaN         NaN
# 1    E002      D002      Bob  41.0  62247.0       NaN       NaN         NaN
# 2    E003      D004  Charlie  30.0  53546.0       NaN       NaN         NaN
# 3    E004      D001    David  46.0  43066.0       NaN       NaN         NaN
# 4    E005      D002   Evelyn  32.0  42264.0       NaN       NaN         NaN
# 5    E006      D001    Frank  47.0  79051.0       NaN       NaN         NaN
# 6    E007      D004    Grace  31.0  51542.0       NaN       NaN         NaN
# 7    E008      D002    Helen  31.0  72880.0       NaN       NaN         NaN
# 8    E009      D001      Ian  26.0  68708.0       NaN       NaN         NaN
# 9    E010      D002     Jane  47.0  79140.0      D002    Sydney         3.0
# 10   E011      D003     Karl  39.0  47488.0      D002     Tokyo        12.0
# 11   E012      D003     Lina  42.0  86429.0      D001     Tokyo         2.0
# 12   E013      D001     Mike  37.0  46319.0      D005    London         7.0
# 13   E014      D004     Nina  42.0  51768.0      D002     Tokyo        10.0
# 14   E015      D003     Owen  30.0  55434.0      D005    Sydney        11.0
# 15   E016      D001     Paul  33.0  68002.0      D005     Tokyo         5.0
# 16   E017      D004    Queen  34.0  85616.0      D001    Sydney        14.0
# 17   E018      D003     Rita  25.0  59459.0      D001    Sydney         7.0
# 18   E019      D003    Steve  42.0  79202.0      D005     Tokyo        14.0
# 19   E020      D004     Tina  47.0  44057.0      D005  New York        14.0
# 20   E021       NaN      NaN   NaN      NaN      D005    Sydney         3.0
# 21   E022       NaN      NaN   NaN      NaN      D005     Tokyo        13.0
# 22   E023       NaN      NaN   NaN      NaN      D001    Sydney         9.0
# 23   E024       NaN      NaN   NaN      NaN      D005  New York         3.0
# 24   E025       NaN      NaN   NaN      NaN      D001  New York         2.0
# 25   E026       NaN      NaN   NaN      NaN      D005     Tokyo        10.0
# 26   E027       NaN      NaN   NaN      NaN      D001  New York         1.0
# 27   E028       NaN      NaN   NaN      NaN      D005     Tokyo        11.0
# 28   E029       NaN      NaN   NaN      NaN      D002    Sydney        10.0
#
#      Bonus
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9   9574.0
# 10  6596.0
# 11  8977.0
# 12  8311.0
# 13  4509.0
# 14  7031.0
# 15  9622.0
# 16  7836.0
# 17  2649.0
# 18  5529.0
# 19  3069.0
# 20  3329.0
# 21  5212.0
# 22  6977.0
# 23  9638.0
# 24  8783.0
# 25  8214.0
# 26  5636.0
# 27  8348.0
# 28  4009.0

# %% [markdown]
# ### 02 - Joining

# %%
students_df = pd.read_csv(r'Dataframes\students.csv')
exam_df = pd.read_csv(r'Dataframes\exam_scores.csv')
attendance_df = pd.read_csv(r'Dataframes\attendance.csv', index_col=0)  # index column retained
class_scores_df = pd.read_csv(r'Dataframes\class_scores.csv')

# %% [markdown]
# Setting the index

# %%
students_df
# Out:
#    Student_ID      Name Grade
# 0           1      Amal     A
# 1           2      Binu     B
# 2           3  Chathura     A
# 3           4   Dewmini     C
# 4           5     Eshan     B
# 5           6     Farah     A
# 6           7     Gayan     C
# 7           8    Hiruni     B
# 8           9    Ishara     A
# 9          10    Janith     B

# %%
students_df.set_index('Student_ID')
# Out:
#                 Name Grade
# Student_ID
# 1               Amal     A
# 2               Binu     B
# 3           Chathura     A
# 4            Dewmini     C
# 5              Eshan     B
# 6              Farah     A
# 7              Gayan     C
# 8             Hiruni     B
# 9             Ishara     A
# 10            Janith     B

# %%
exam_df
# Out:
#    Student_ID  Math_Score  Science_Score
# 0           1          85             90
# 1           2          76             82
# 2           3          92             89
# 3           5          67             70
# 4           6          88             85
# 5           8          79             75
# 6           9          95             91

# %%
attendance_df
# Out:
#           Days_Present  Days_Total
# Amal                40          45
# Binu                38          45
# Chathura            45          45
# Dewmini             30          45
# Eshan               36          45
# Farah               43          45
# Gayan               42          45
# Hiruni              33          45

# %%
# Setting the index
students_indexed = students_df.set_index('Student_ID')
exam_indexed = exam_df.set_index('Student_ID')

# %%
# Inner join by index
join_inner = students_indexed.join(exam_indexed, how='inner')
print("Join by Index (Inner Join):")
join_inner
# Out:
# Join by Index (Inner Join):
#                 Name Grade  Math_Score  Science_Score
# Student_ID
# 1               Amal     A          85             90
# 2               Binu     B          76             82
# 3           Chathura     A          92             89
# 5              Eshan     B          67             70
# 6              Farah     A          88             85
# 8             Hiruni     B          79             75
# 9             Ishara     A          95             91

# %%
# Inner join by index
join_inner = students_indexed.join(exam_indexed, how='right')
print("Join by Index (Inner Join):")
join_inner
# Out:
# Join by Index (Inner Join):
#                 Name Grade  Math_Score  Science_Score
# Student_ID
# 1               Amal     A          85             90
# 2               Binu     B          76             82
# 3           Chathura     A          92             89
# 5              Eshan     B          67             70
# 6              Farah     A          88             85
# 8             Hiruni     B          79             75
# 9             Ishara     A          95             91

# %%
# Outer join by index
join_outer = students_indexed.join(exam_indexed, how='outer')
print("Join by Index (Outer Join):")
join_outer
# Out:
# Join by Index (Outer Join):
#                 Name Grade  Math_Score  Science_Score
# Student_ID
# 1               Amal     A        85.0           90.0
# 2               Binu     B        76.0           82.0
# 3           Chathura     A        92.0           89.0
# 4            Dewmini     C         NaN            NaN
# 5              Eshan     B        67.0           70.0
# 6              Farah     A        88.0           85.0
# 7              Gayan     C         NaN            NaN
# 8             Hiruni     B        79.0           75.0
# 9             Ishara     A        95.0           91.0
# 10            Janith     B         NaN            NaN

# %%
# Join using 'on' argument (attendance)
join_on = students_df.join(attendance_df, on='Name', how='left')
print("Join using 'on' argument (Attendance by Name):")
join_on
# Out:
# Join using 'on' argument (Attendance by Name):
#    Student_ID      Name Grade  Days_Present  Days_Total
# 0           1      Amal     A          40.0        45.0
# 1           2      Binu     B          38.0        45.0
# 2           3  Chathura     A          45.0        45.0
# 3           4   Dewmini     C          30.0        45.0
# 4           5     Eshan     B          36.0        45.0
# 5           6     Farah     A          43.0        45.0
# 6           7     Gayan     C          42.0        45.0
# 7           8    Hiruni     B          33.0        45.0
# 8           9    Ishara     A           NaN         NaN
# 9          10    Janith     B           NaN         NaN

# %%
# Join using 'on' argument (attendance)
join_on = students_df.join(attendance_df, on='Name', how='right')
print("Join using 'on' argument (Attendance by Name):")
join_on
# Out:
# Join using 'on' argument (Attendance by Name):
#    Student_ID      Name Grade  Days_Present  Days_Total
# 0           1      Amal     A            40          45
# 1           2      Binu     B            38          45
# 2           3  Chathura     A            45          45
# 3           4   Dewmini     C            30          45
# 4           5     Eshan     B            36          45
# 5           6     Farah     A            43          45
# 6           7     Gayan     C            42          45
# 7           8    Hiruni     B            33          45

# %% [markdown]
# ### 03 - Concatenation

# %% [markdown]
# Concatenating DataFrames Horizontally

# %%
df_A
# Out:
#    Emp_ID Dept_ID     Name  Age  Salary
# 0    E001    D001    Alice   49   69779
# 1    E002    D002      Bob   41   62247
# 2    E003    D004  Charlie   30   53546
# 3    E004    D001    David   46   43066
# 4    E005    D002   Evelyn   32   42264
# 5    E006    D001    Frank   47   79051
# 6    E007    D004    Grace   31   51542
# 7    E008    D002    Helen   31   72880
# 8    E009    D001      Ian   26   68708
# 9    E010    D002     Jane   47   79140
# 10   E011    D003     Karl   39   47488
# 11   E012    D003     Lina   42   86429
# 12   E013    D001     Mike   37   46319
# 13   E014    D004     Nina   42   51768
# 14   E015    D003     Owen   30   55434
# 15   E016    D001     Paul   33   68002
# 16   E017    D004    Queen   34   85616
# 17   E018    D003     Rita   25   59459
# 18   E019    D003    Steve   42   79202
# 19   E020    D004     Tina   47   44057

# %%
df_B
# Out:
#    Emp_ID Dept_ID  Location  Experience  Bonus
# 0    E010    D002    Sydney           3   9574
# 1    E011    D002     Tokyo          12   6596
# 2    E012    D001     Tokyo           2   8977
# 3    E013    D005    London           7   8311
# 4    E014    D002     Tokyo          10   4509
# 5    E015    D005    Sydney          11   7031
# 6    E016    D005     Tokyo           5   9622
# 7    E017    D001    Sydney          14   7836
# 8    E018    D001    Sydney           7   2649
# 9    E019    D005     Tokyo          14   5529
# 10   E020    D005  New York          14   3069
# 11   E021    D005    Sydney           3   3329
# 12   E022    D005     Tokyo          13   5212
# 13   E023    D001    Sydney           9   6977
# 14   E024    D005  New York           3   9638
# 15   E025    D001  New York           2   8783
# 16   E026    D005     Tokyo          10   8214
# 17   E027    D001  New York           1   5636
# 18   E028    D005     Tokyo          11   8348
# 19   E029    D002    Sydney          10   4009

# %%
concat_v = pd.concat([df_A, df_B])
print(concat_v.shape)
concat_v
# Out:
# (40, 8)
#    Emp_ID Dept_ID     Name   Age   Salary  Location  Experience   Bonus
# 0    E001    D001    Alice  49.0  69779.0       NaN         NaN     NaN
# 1    E002    D002      Bob  41.0  62247.0       NaN         NaN     NaN
# 2    E003    D004  Charlie  30.0  53546.0       NaN         NaN     NaN
# 3    E004    D001    David  46.0  43066.0       NaN         NaN     NaN
# 4    E005    D002   Evelyn  32.0  42264.0       NaN         NaN     NaN
# 5    E006    D001    Frank  47.0  79051.0       NaN         NaN     NaN
# 6    E007    D004    Grace  31.0  51542.0       NaN         NaN     NaN
# 7    E008    D002    Helen  31.0  72880.0       NaN         NaN     NaN
# 8    E009    D001      Ian  26.0  68708.0       NaN         NaN     NaN
# 9    E010    D002     Jane  47.0  79140.0       NaN         NaN     NaN
# 10   E011    D003     Karl  39.0  47488.0       NaN         NaN     NaN
# 11   E012    D003     Lina  42.0  86429.0       NaN         NaN     NaN
# 12   E013    D001     Mike  37.0  46319.0       NaN         NaN     NaN
# 13   E014    D004     Nina  42.0  51768.0       NaN         NaN     NaN
# 14   E015    D003     Owen  30.0  55434.0       NaN         NaN     NaN
# 15   E016    D001     Paul  33.0  68002.0       NaN         NaN     NaN
# 16   E017    D004    Queen  34.0  85616.0       NaN         NaN     NaN
# 17   E018    D003     Rita  25.0  59459.0       NaN         NaN     NaN
# 18   E019    D003    Steve  42.0  79202.0       NaN         NaN     NaN
# 19   E020    D004     Tina  47.0  44057.0       NaN         NaN     NaN
# 0    E010    D002      NaN   NaN      NaN    Sydney         3.0  9574.0
# 1    E011    D002      NaN   NaN      NaN     Tokyo        12.0  6596.0
# 2    E012    D001      NaN   NaN      NaN     Tokyo         2.0  8977.0
# 3    E013    D005      NaN   NaN      NaN    London         7.0  8311.0
# 4    E014    D002      NaN   NaN      NaN     Tokyo        10.0  4509.0
# 5    E015    D005      NaN   NaN      NaN    Sydney        11.0  7031.0
# 6    E016    D005      NaN   NaN      NaN     Tokyo         5.0  9622.0
# 7    E017    D001      NaN   NaN      NaN    Sydney        14.0  7836.0
# 8    E018    D001      NaN   NaN      NaN    Sydney         7.0  2649.0
# 9    E019    D005      NaN   NaN      NaN     Tokyo        14.0  5529.0
# 10   E020    D005      NaN   NaN      NaN  New York        14.0  3069.0
# 11   E021    D005      NaN   NaN      NaN    Sydney         3.0  3329.0
# 12   E022    D005      NaN   NaN      NaN     Tokyo        13.0  5212.0
# 13   E023    D001      NaN   NaN      NaN    Sydney         9.0  6977.0
# 14   E024    D005      NaN   NaN      NaN  New York         3.0  9638.0
# 15   E025    D001      NaN   NaN      NaN  New York         2.0  8783.0
# 16   E026    D005      NaN   NaN      NaN     Tokyo        10.0  8214.0
# 17   E027    D001      NaN   NaN      NaN  New York         1.0  5636.0
# 18   E028    D005      NaN   NaN      NaN     Tokyo        11.0  8348.0
# 19   E029    D002      NaN   NaN      NaN    Sydney        10.0  4009.0

# %% [markdown]
# Concatenating DataFrames Horizontally

# %%
concat_h = pd.concat([df_B, df_A], axis=1)
concat_h
# Out:
#    Emp_ID Dept_ID  Location  Experience  Bonus Emp_ID Dept_ID     Name  Age  \
# 0    E010    D002    Sydney           3   9574   E001    D001    Alice   49
# 1    E011    D002     Tokyo          12   6596   E002    D002      Bob   41
# 2    E012    D001     Tokyo           2   8977   E003    D004  Charlie   30
# 3    E013    D005    London           7   8311   E004    D001    David   46
# 4    E014    D002     Tokyo          10   4509   E005    D002   Evelyn   32
# 5    E015    D005    Sydney          11   7031   E006    D001    Frank   47
# 6    E016    D005     Tokyo           5   9622   E007    D004    Grace   31
# 7    E017    D001    Sydney          14   7836   E008    D002    Helen   31
# 8    E018    D001    Sydney           7   2649   E009    D001      Ian   26
# 9    E019    D005     Tokyo          14   5529   E010    D002     Jane   47
# 10   E020    D005  New York          14   3069   E011    D003     Karl   39
# 11   E021    D005    Sydney           3   3329   E012    D003     Lina   42
# 12   E022    D005     Tokyo          13   5212   E013    D001     Mike   37
# 13   E023    D001    Sydney           9   6977   E014    D004     Nina   42
# 14   E024    D005  New York           3   9638   E015    D003     Owen   30
# 15   E025    D001  New York           2   8783   E016    D001     Paul   33
# 16   E026    D005     Tokyo          10   8214   E017    D004    Queen   34
# 17   E027    D001  New York           1   5636   E018    D003     Rita   25
# 18   E028    D005     Tokyo          11   8348   E019    D003    Steve   42
# 19   E029    D002    Sydney          10   4009   E020    D004     Tina   47
#
#     Salary
# 0    69779
# 1    62247
# 2    53546
# 3    43066
# 4    42264
# 5    79051
# 6    51542
# 7    72880
# 8    68708
# 9    79140
# 10   47488
# 11   86429
# 12   46319
# 13   51768
# 14   55434
# 15   68002
# 16   85616
# 17   59459
# 18   79202
# 19   44057

# %% [markdown]
# Concatenating with Join Logic on Axes

# %%
df_A
# Out:
#    Emp_ID Dept_ID     Name  Age  Salary
# 0    E001    D001    Alice   49   69779
# 1    E002    D002      Bob   41   62247
# 2    E003    D004  Charlie   30   53546
# 3    E004    D001    David   46   43066
# 4    E005    D002   Evelyn   32   42264
# 5    E006    D001    Frank   47   79051
# 6    E007    D004    Grace   31   51542
# 7    E008    D002    Helen   31   72880
# 8    E009    D001      Ian   26   68708
# 9    E010    D002     Jane   47   79140
# 10   E011    D003     Karl   39   47488
# 11   E012    D003     Lina   42   86429
# 12   E013    D001     Mike   37   46319
# 13   E014    D004     Nina   42   51768
# 14   E015    D003     Owen   30   55434
# 15   E016    D001     Paul   33   68002
# 16   E017    D004    Queen   34   85616
# 17   E018    D003     Rita   25   59459
# 18   E019    D003    Steve   42   79202
# 19   E020    D004     Tina   47   44057

# %%
df_B
# Out:
#    Emp_ID Dept_ID  Location  Experience  Bonus
# 0    E010    D002    Sydney           3   9574
# 1    E011    D002     Tokyo          12   6596
# 2    E012    D001     Tokyo           2   8977
# 3    E013    D005    London           7   8311
# 4    E014    D002     Tokyo          10   4509
# 5    E015    D005    Sydney          11   7031
# 6    E016    D005     Tokyo           5   9622
# 7    E017    D001    Sydney          14   7836
# 8    E018    D001    Sydney           7   2649
# 9    E019    D005     Tokyo          14   5529
# 10   E020    D005  New York          14   3069
# 11   E021    D005    Sydney           3   3329
# 12   E022    D005     Tokyo          13   5212
# 13   E023    D001    Sydney           9   6977
# 14   E024    D005  New York           3   9638
# 15   E025    D001  New York           2   8783
# 16   E026    D005     Tokyo          10   8214
# 17   E027    D001  New York           1   5636
# 18   E028    D005     Tokyo          11   8348
# 19   E029    D002    Sydney          10   4009

# %%
concat_inner = pd.concat([df_A, df_B], axis=1, join='inner')
concat_inner
# Out:
#    Emp_ID Dept_ID     Name  Age  Salary Emp_ID Dept_ID  Location  Experience  \
# 0    E001    D001    Alice   49   69779   E010    D002    Sydney           3
# 1    E002    D002      Bob   41   62247   E011    D002     Tokyo          12
# 2    E003    D004  Charlie   30   53546   E012    D001     Tokyo           2
# 3    E004    D001    David   46   43066   E013    D005    London           7
# 4    E005    D002   Evelyn   32   42264   E014    D002     Tokyo          10
# 5    E006    D001    Frank   47   79051   E015    D005    Sydney          11
# 6    E007    D004    Grace   31   51542   E016    D005     Tokyo           5
# 7    E008    D002    Helen   31   72880   E017    D001    Sydney          14
# 8    E009    D001      Ian   26   68708   E018    D001    Sydney           7
# 9    E010    D002     Jane   47   79140   E019    D005     Tokyo          14
# 10   E011    D003     Karl   39   47488   E020    D005  New York          14
# 11   E012    D003     Lina   42   86429   E021    D005    Sydney           3
# 12   E013    D001     Mike   37   46319   E022    D005     Tokyo          13
# 13   E014    D004     Nina   42   51768   E023    D001    Sydney           9
# 14   E015    D003     Owen   30   55434   E024    D005  New York           3
# 15   E016    D001     Paul   33   68002   E025    D001  New York           2
# 16   E017    D004    Queen   34   85616   E026    D005     Tokyo          10
# 17   E018    D003     Rita   25   59459   E027    D001  New York           1
# 18   E019    D003    Steve   42   79202   E028    D005     Tokyo          11
# 19   E020    D004     Tina   47   44057   E029    D002    Sydney          10
#
#     Bonus
# 0    9574
# 1    6596
# 2    8977
# 3    8311
# 4    4509
# 5    7031
# 6    9622
# 7    7836
# 8    2649
# 9    5529
# 10   3069
# 11   3329
# 12   5212
# 13   6977
# 14   9638
# 15   8783
# 16   8214
# 17   5636
# 18   8348
# 19   4009

# %%
concat_outer = pd.concat([df_A, df_B], axis=1, join='outer')
concat_outer
# Out:
#    Emp_ID Dept_ID     Name  Age  Salary Emp_ID Dept_ID  Location  Experience  \
# 0    E001    D001    Alice   49   69779   E010    D002    Sydney           3
# 1    E002    D002      Bob   41   62247   E011    D002     Tokyo          12
# 2    E003    D004  Charlie   30   53546   E012    D001     Tokyo           2
# 3    E004    D001    David   46   43066   E013    D005    London           7
# 4    E005    D002   Evelyn   32   42264   E014    D002     Tokyo          10
# 5    E006    D001    Frank   47   79051   E015    D005    Sydney          11
# 6    E007    D004    Grace   31   51542   E016    D005     Tokyo           5
# 7    E008    D002    Helen   31   72880   E017    D001    Sydney          14
# 8    E009    D001      Ian   26   68708   E018    D001    Sydney           7
# 9    E010    D002     Jane   47   79140   E019    D005     Tokyo          14
# 10   E011    D003     Karl   39   47488   E020    D005  New York          14
# 11   E012    D003     Lina   42   86429   E021    D005    Sydney           3
# 12   E013    D001     Mike   37   46319   E022    D005     Tokyo          13
# 13   E014    D004     Nina   42   51768   E023    D001    Sydney           9
# 14   E015    D003     Owen   30   55434   E024    D005  New York           3
# 15   E016    D001     Paul   33   68002   E025    D001  New York           2
# 16   E017    D004    Queen   34   85616   E026    D005     Tokyo          10
# 17   E018    D003     Rita   25   59459   E027    D001  New York           1
# 18   E019    D003    Steve   42   79202   E028    D005     Tokyo          11
# 19   E020    D004     Tina   47   44057   E029    D002    Sydney          10
#
#     Bonus
# 0    9574
# 1    6596
# 2    8977
# 3    8311
# 4    4509
# 5    7031
# 6    9622
# 7    7836
# 8    2649
# 9    5529
# 10   3069
# 11   3329
# 12   5212
# 13   6977
# 14   9638
# 15   8783
# 16   8214
# 17   5636
# 18   8348
# 19   4009

# %%
print(f"Inner: {concat_inner.shape}\nOuter: {concat_outer.shape}")
# Out:
# Inner: (20, 10)
# Outer: (20, 10)

# %% [markdown]
# We need to be very careful when joining to avoid concatenation of unrelated columns!

# %%
print("Inner join concat:")
concat_inner.head()
# Out:
# Inner join concat:
#   Emp_ID Dept_ID     Name  Age  Salary Emp_ID Dept_ID Location  Experience  \
# 0   E001    D001    Alice   49   69779   E010    D002   Sydney           3
# 1   E002    D002      Bob   41   62247   E011    D002    Tokyo          12
# 2   E003    D004  Charlie   30   53546   E012    D001    Tokyo           2
# 3   E004    D001    David   46   43066   E013    D005   London           7
# 4   E005    D002   Evelyn   32   42264   E014    D002    Tokyo          10
#
#    Bonus
# 0   9574
# 1   6596
# 2   8977
# 3   8311
# 4   4509

# %%
print("Outer join concat:")
concat_outer.head()
# Out:
# Outer join concat:
#   Emp_ID Dept_ID     Name  Age  Salary Emp_ID Dept_ID Location  Experience  \
# 0   E001    D001    Alice   49   69779   E010    D002   Sydney           3
# 1   E002    D002      Bob   41   62247   E011    D002    Tokyo          12
# 2   E003    D004  Charlie   30   53546   E012    D001    Tokyo           2
# 3   E004    D001    David   46   43066   E013    D005   London           7
# 4   E005    D002   Evelyn   32   42264   E014    D002    Tokyo          10
#
#    Bonus
# 0   9574
# 1   6596
# 2   8977
# 3   8311
# 4   4509

# %% [markdown]
# Concatenating DataFrames by Ignoring Indexes

# %%
concat_ignore = pd.concat([df_A, df_B], ignore_index=True)
concat_ignore
# Out:
#    Emp_ID Dept_ID     Name   Age   Salary  Location  Experience   Bonus
# 0    E001    D001    Alice  49.0  69779.0       NaN         NaN     NaN
# 1    E002    D002      Bob  41.0  62247.0       NaN         NaN     NaN
# 2    E003    D004  Charlie  30.0  53546.0       NaN         NaN     NaN
# 3    E004    D001    David  46.0  43066.0       NaN         NaN     NaN
# 4    E005    D002   Evelyn  32.0  42264.0       NaN         NaN     NaN
# 5    E006    D001    Frank  47.0  79051.0       NaN         NaN     NaN
# 6    E007    D004    Grace  31.0  51542.0       NaN         NaN     NaN
# 7    E008    D002    Helen  31.0  72880.0       NaN         NaN     NaN
# 8    E009    D001      Ian  26.0  68708.0       NaN         NaN     NaN
# 9    E010    D002     Jane  47.0  79140.0       NaN         NaN     NaN
# 10   E011    D003     Karl  39.0  47488.0       NaN         NaN     NaN
# 11   E012    D003     Lina  42.0  86429.0       NaN         NaN     NaN
# 12   E013    D001     Mike  37.0  46319.0       NaN         NaN     NaN
# 13   E014    D004     Nina  42.0  51768.0       NaN         NaN     NaN
# 14   E015    D003     Owen  30.0  55434.0       NaN         NaN     NaN
# 15   E016    D001     Paul  33.0  68002.0       NaN         NaN     NaN
# 16   E017    D004    Queen  34.0  85616.0       NaN         NaN     NaN
# 17   E018    D003     Rita  25.0  59459.0       NaN         NaN     NaN
# 18   E019    D003    Steve  42.0  79202.0       NaN         NaN     NaN
# 19   E020    D004     Tina  47.0  44057.0       NaN         NaN     NaN
# 20   E010    D002      NaN   NaN      NaN    Sydney         3.0  9574.0
# 21   E011    D002      NaN   NaN      NaN     Tokyo        12.0  6596.0
# 22   E012    D001      NaN   NaN      NaN     Tokyo         2.0  8977.0
# 23   E013    D005      NaN   NaN      NaN    London         7.0  8311.0
# 24   E014    D002      NaN   NaN      NaN     Tokyo        10.0  4509.0
# 25   E015    D005      NaN   NaN      NaN    Sydney        11.0  7031.0
# 26   E016    D005      NaN   NaN      NaN     Tokyo         5.0  9622.0
# 27   E017    D001      NaN   NaN      NaN    Sydney        14.0  7836.0
# 28   E018    D001      NaN   NaN      NaN    Sydney         7.0  2649.0
# 29   E019    D005      NaN   NaN      NaN     Tokyo        14.0  5529.0
# 30   E020    D005      NaN   NaN      NaN  New York        14.0  3069.0
# 31   E021    D005      NaN   NaN      NaN    Sydney         3.0  3329.0
# 32   E022    D005      NaN   NaN      NaN     Tokyo        13.0  5212.0
# 33   E023    D001      NaN   NaN      NaN    Sydney         9.0  6977.0
# 34   E024    D005      NaN   NaN      NaN  New York         3.0  9638.0
# 35   E025    D001      NaN   NaN      NaN  New York         2.0  8783.0
# 36   E026    D005      NaN   NaN      NaN     Tokyo        10.0  8214.0
# 37   E027    D001      NaN   NaN      NaN  New York         1.0  5636.0
# 38   E028    D005      NaN   NaN      NaN     Tokyo        11.0  8348.0
# 39   E029    D002      NaN   NaN      NaN    Sydney        10.0  4009.0

# %% [markdown]
# Concatenating with Group Keys

# %%
concat_keys = pd.concat([df_A, df_B], keys=['Group_A', 'Group_B'])
concat_keys
# Out:
#            Emp_ID Dept_ID     Name   Age   Salary  Location  Experience  \
# Group_A 0    E001    D001    Alice  49.0  69779.0       NaN         NaN
#         1    E002    D002      Bob  41.0  62247.0       NaN         NaN
#         2    E003    D004  Charlie  30.0  53546.0       NaN         NaN
#         3    E004    D001    David  46.0  43066.0       NaN         NaN
#         4    E005    D002   Evelyn  32.0  42264.0       NaN         NaN
#         5    E006    D001    Frank  47.0  79051.0       NaN         NaN
#         6    E007    D004    Grace  31.0  51542.0       NaN         NaN
#         7    E008    D002    Helen  31.0  72880.0       NaN         NaN
#         8    E009    D001      Ian  26.0  68708.0       NaN         NaN
#         9    E010    D002     Jane  47.0  79140.0       NaN         NaN
#         10   E011    D003     Karl  39.0  47488.0       NaN         NaN
#         11   E012    D003     Lina  42.0  86429.0       NaN         NaN
#         12   E013    D001     Mike  37.0  46319.0       NaN         NaN
#         13   E014    D004     Nina  42.0  51768.0       NaN         NaN
#         14   E015    D003     Owen  30.0  55434.0       NaN         NaN
#         15   E016    D001     Paul  33.0  68002.0       NaN         NaN
#         16   E017    D004    Queen  34.0  85616.0       NaN         NaN
#         17   E018    D003     Rita  25.0  59459.0       NaN         NaN
#         18   E019    D003    Steve  42.0  79202.0       NaN         NaN
#         19   E020    D004     Tina  47.0  44057.0       NaN         NaN
# Group_B 0    E010    D002      NaN   NaN      NaN    Sydney         3.0
#         1    E011    D002      NaN   NaN      NaN     Tokyo        12.0
#         2    E012    D001      NaN   NaN      NaN     Tokyo         2.0
#         3    E013    D005      NaN   NaN      NaN    London         7.0
#         4    E014    D002      NaN   NaN      NaN     Tokyo        10.0
#         5    E015    D005      NaN   NaN      NaN    Sydney        11.0
#         6    E016    D005      NaN   NaN      NaN     Tokyo         5.0
#         7    E017    D001      NaN   NaN      NaN    Sydney        14.0
#         8    E018    D001      NaN   NaN      NaN    Sydney         7.0
#         9    E019    D005      NaN   NaN      NaN     Tokyo        14.0
#         10   E020    D005      NaN   NaN      NaN  New York        14.0
#         11   E021    D005      NaN   NaN      NaN    Sydney         3.0
#         12   E022    D005      NaN   NaN      NaN     Tokyo        13.0
#         13   E023    D001      NaN   NaN      NaN    Sydney         9.0
#         14   E024    D005      NaN   NaN      NaN  New York         3.0
#         15   E025    D001      NaN   NaN      NaN  New York         2.0
#         16   E026    D005      NaN   NaN      NaN     Tokyo        10.0
#         17   E027    D001      NaN   NaN      NaN  New York         1.0
#         18   E028    D005      NaN   NaN      NaN     Tokyo        11.0
#         19   E029    D002      NaN   NaN      NaN    Sydney        10.0
#
#              Bonus
# Group_A 0      NaN
#         1      NaN
#         2      NaN
#         3      NaN
#         4      NaN
#         5      NaN
#         6      NaN
#         7      NaN
#         8      NaN
#         9      NaN
#         10     NaN
#         11     NaN
#         12     NaN
#         13     NaN
#         14     NaN
#         15     NaN
#         16     NaN
#         17     NaN
#         18     NaN
#         19     NaN
# Group_B 0   9574.0
#         1   6596.0
#         2   8977.0
#         3   8311.0
#         4   4509.0
#         5   7031.0
#         6   9622.0
#         7   7836.0
#         8   2649.0
#         9   5529.0
#         10  3069.0
#         11  3329.0
#         12  5212.0
#         13  6977.0
#         14  9638.0
#         15  8783.0
#         16  8214.0
#         17  5636.0
#         18  8348.0
#         19  4009.0

# %% [markdown]
# ### Additional methods

# %%
df = concat_keys.reset_index()
df.head()
# Out:
#    level_0  level_1 Emp_ID Dept_ID     Name   Age   Salary Location  \
# 0  Group_A        0   E001    D001    Alice  49.0  69779.0      NaN
# 1  Group_A        1   E002    D002      Bob  41.0  62247.0      NaN
# 2  Group_A        2   E003    D004  Charlie  30.0  53546.0      NaN
# 3  Group_A        3   E004    D001    David  46.0  43066.0      NaN
# 4  Group_A        4   E005    D002   Evelyn  32.0  42264.0      NaN
#
#    Experience  Bonus
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
df = df.drop(columns=['level_1'], errors='ignore')
df.head()
# Out:
#    level_0 Emp_ID Dept_ID     Name   Age   Salary Location  Experience  Bonus
# 0  Group_A   E001    D001    Alice  49.0  69779.0      NaN         NaN    NaN
# 1  Group_A   E002    D002      Bob  41.0  62247.0      NaN         NaN    NaN
# 2  Group_A   E003    D004  Charlie  30.0  53546.0      NaN         NaN    NaN
# 3  Group_A   E004    D001    David  46.0  43066.0      NaN         NaN    NaN
# 4  Group_A   E005    D002   Evelyn  32.0  42264.0      NaN         NaN    NaN

# %%
df = df.rename(columns={'level_0': 'Group'})
df.head()
# Out:
#      Group Emp_ID Dept_ID     Name   Age   Salary Location  Experience  Bonus
# 0  Group_A   E001    D001    Alice  49.0  69779.0      NaN         NaN    NaN
# 1  Group_A   E002    D002      Bob  41.0  62247.0      NaN         NaN    NaN
# 2  Group_A   E003    D004  Charlie  30.0  53546.0      NaN         NaN    NaN
# 3  Group_A   E004    D001    David  46.0  43066.0      NaN         NaN    NaN
# 4  Group_A   E005    D002   Evelyn  32.0  42264.0      NaN         NaN    NaN
