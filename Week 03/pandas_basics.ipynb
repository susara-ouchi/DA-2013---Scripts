# %% [markdown]
# ### Data Management with Pandas

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import the data

# %%
df = pd.read_csv("sri_lanka_employees.csv")
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena   4/1/2022   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne   4/1/2024  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe  12/1/2021    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera  12/1/2019  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake   6/1/2019   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis   2/1/2017    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis   9/1/2022    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando   5/1/2019    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake   1/1/2021    Kandy          HR       NaN
# 99        97538      Malsha Bandara  10/1/2025    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df_0 = df.copy()
df_0
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena   4/1/2022   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne   4/1/2024  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe  12/1/2021    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera  12/1/2019  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake   6/1/2019   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis   2/1/2017    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis   9/1/2022    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando   5/1/2019    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake   1/1/2021    Kandy          HR       NaN
# 99        97538      Malsha Bandara  10/1/2025    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Study the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  100 non-null    int64
#  1   Name         100 non-null    object
#  2   Join_Date    100 non-null    object
#  3   City         100 non-null    object
#  4   Department   100 non-null    object
#  5   Salary       80 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#         Employee_ID         Salary
# count    100.000000      80.000000
# mean   58544.920000   96157.500000
# std    27846.019844   31583.971961
# min    10769.000000   50400.000000
# 25%    33793.500000   69875.000000
# 50%    63351.000000   88750.000000
# 75%    79912.000000  122975.000000
# max    99812.000000  149600.000000

# %%
df.describe(include="all")
# Out:
#          Employee_ID               Name Join_Date    City Department  \
# count     100.000000                100       100     100        100
# unique           NaN                 69        68       4          5
# top              NaN  Ishara Rathnayake  4/1/2022  Jaffna         HR
# freq             NaN                  3         4      29         25
# mean    58544.920000                NaN       NaN     NaN        NaN
# std     27846.019844                NaN       NaN     NaN        NaN
# min     10769.000000                NaN       NaN     NaN        NaN
# 25%     33793.500000                NaN       NaN     NaN        NaN
# 50%     63351.000000                NaN       NaN     NaN        NaN
# 75%     79912.000000                NaN       NaN     NaN        NaN
# max     99812.000000                NaN       NaN     NaN        NaN
#
#                Salary
# count       80.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
df.sample(n=10)
# Out:
#     Employee_ID                Name  Join_Date    City  Department    Salary
# 0         25795   Nuwan Gunawardena   4/1/2022  Jaffna          HR   73200.0
# 2         86820    Nuwan Jayasinghe  12/1/2021   Kandy     Finance   59500.0
# 52        27159       Nuwan Bandara   3/1/2018   Kandy     Finance       NaN
# 99        97538      Malsha Bandara  10/1/2025   Kandy  Operations  134600.0
# 51        58555   Nuwan Gunawardena   4/1/2015  Jaffna          IT   51000.0
# 56        79479       Nuwan Bandara   4/1/2021   Kandy          HR   56800.0
# 12        77221  Janith Karunaratne  12/1/2016  Jaffna  Operations  119400.0
# 9         70263  Sajith Gunawardena   4/1/2018   Galle          HR   54000.0
# 89        61214      Ishara Bandara   6/1/2021  Jaffna          HR  121700.0
# 15        69735    Nuwan Jayasinghe  10/1/2017  Jaffna  Operations       NaN

# %%
df.dtypes
# Out:
# Employee_ID      int64
# Name            object
# Join_Date       object
# City            object
# Department      object
# Salary         float64
# dtype: object

# %%
df["Join_Date"] = pd.to_datetime(df["Join_Date"], errors = 'coerce')
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Getting counts of data using value count

# %%
df.value_counts()
# Out:
# Employee_ID  Name                  Join_Date   City     Department  Salary
# 10860        Rashmi Karunaratne    2024-04-01  Colombo  Finance     59800.0     1
# 11016        Chamari Perera        2025-10-01  Colombo  Marketing   65400.0     1
# 79479        Nuwan Bandara         2021-04-01  Kandy    HR          56800.0     1
# 79092        Janith Gunawardena    2023-08-01  Colombo  Operations  50700.0     1
# 78148        Suresh Karunaratne    2025-09-01  Colombo  Operations  147200.0    1
#                                                                                ..
# 48044        Chamari Silva         2025-12-01  Kandy    HR          141300.0    1
# 47194        Nadeesha Gunawardena  2020-02-01  Jaffna   HR          138200.0    1
# 47065        Rashmi Karunaratne    2024-02-01  Colombo  Marketing   85900.0     1
# 45920        Tharushi Fernando     2021-11-01  Kandy    Operations  59300.0     1
# ...

# %%
df['City'].value_counts()
# Out:
# City
# Jaffna     29
# Colombo    24
# Kandy      24
# Galle      23
# Name: count, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Name
# Ishara Rathnayake     3
# Nuwan Jayasinghe      3
# Malsha Bandara        3
# Rashmi Karunaratne    3
# Janith Gunawardena    3
#                      ..
# Ruwan Silva           1
# Suresh Karunaratne    1
# Suresh De Alwis       1
# Tharushi Fernando     1
# Kasun De Alwis        1
# Name: count, Length: 69, dtype: int64

# %%
df['Employee_ID'].value_counts()
# Out:
# Employee_ID
# 25795    1
# 50757    1
# 11016    1
# 50397    1
# 21534    1
#         ..
# 75725    1
# 69150    1
# 12747    1
# 28431    1
# 97538    1
# Name: count, Length: 100, dtype: int64

# %%
len(df) - df['Name'].nunique()
# Out:
# 31

# %% [markdown]
# Dropping duplicates

# %%
df_0
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena   4/1/2022   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne   4/1/2024  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe  12/1/2021    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera  12/1/2019  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake   6/1/2019   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis   2/1/2017    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis   9/1/2022    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando   5/1/2019    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake   1/1/2021    Kandy          HR       NaN
# 99        97538      Malsha Bandara  10/1/2025    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df_0 == df
# Out:
#     Employee_ID  Name  Join_Date  City  Department  Salary
# 0          True  True       True  True        True    True
# 1          True  True       True  True        True    True
# 2          True  True       True  True        True    True
# 3          True  True       True  True        True    True
# 4          True  True       True  True        True   False
# ..          ...   ...        ...   ...         ...     ...
# 95         True  True       True  True        True    True
# 96         True  True       True  True        True    True
# 97         True  True       True  True        True    True
# 98         True  True       True  True        True   False
# 99         True  True       True  True        True    True
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Observing subsets

# %%
df.iloc[10:20]
# Out:
#     Employee_ID                  Name  Join_Date     City  Department  \
# 10        26023   Dinusha Karunaratne 2016-12-01    Galle     Finance
# 11        51090  Tharushi Gunawardena 2015-04-01  Colombo   Marketing
# 12        77221    Janith Karunaratne 2016-12-01   Jaffna  Operations
# 13        74820     Nuwan Karunaratne 2022-04-01  Colombo          HR
# 14        10769   Dinusha Karunaratne 2021-11-01   Jaffna     Finance
# 15        69735      Nuwan Jayasinghe 2017-10-01   Jaffna  Operations
# 16        72955          Ruwan Perera 2019-11-01    Galle   Marketing
# 17        74925          Kasun Perera 2025-08-01    Galle  Operations
# 18        77969     Ishara Rathnayake 2018-06-01    Kandy     Finance
# 19        15311     Ruwan Karunaratne 2017-10-01    Galle  Operations
#
#       Salary
# 10  143600.0
# 11  147800.0
# 12  119400.0
# 13   70700.0
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18  143000.0
# 19  138600.0

# %%
df["City"]
# Out:
# 0      Jaffna
# 1     Colombo
# 2       Kandy
# 3     Colombo
# 4      Jaffna
#        ...
# 95      Kandy
# 96      Galle
# 97      Galle
# 98      Kandy
# 99      Kandy
# Name: City, Length: 100, dtype: object

# %%
jaffna_df_0 = df.loc[df["City"]=="Jaffna"]
jaffna_df = jaffna_df_0[["Employee_ID", "Name"]]
jaffna_df
# Out:
#     Employee_ID                  Name
# 0         25795     Nuwan Gunawardena
# 4         16265      Ruwan Rathnayake
# 5         92386       Tharushi Perera
# 6         47194  Nadeesha Gunawardena
# 7         97498     Tharushi De Alwis
# 8         54131          Nuwan Perera
# 12        77221    Janith Karunaratne
# 14        10769   Dinusha Karunaratne
# 15        69735      Nuwan Jayasinghe
# 28        12747      Ruwan Rathnayake
# 35        76803     Ishara Rathnayake
# 37        21394         Rashmi Perera
# 40        51606      Kasun Jayasinghe
# 42        97313     Ruwan Gunawardena
# 44        18792    Chamari Rathnayake
# 46        53001         Kasun Bandara
# 48        33897       Tharushi Perera
# 50        33483      Nuwan Jayasinghe
# 51        58555     Nuwan Gunawardena
# 58        29457      Dinusha Fernando
# 61        88953        Ishara Bandara
# 68        75697          Malsha Silva
# 70        42606          Rashmi Silva
# 74        99789    Suresh Gunawardena
# ...

# %%
finance_df = df.loc[df["Department"]=="Finance"]
finance_df
# Out:
#     Employee_ID                 Name  Join_Date     City Department    Salary
# 1         10860   Rashmi Karunaratne 2024-04-01  Colombo    Finance   59800.0
# 2         86820     Nuwan Jayasinghe 2021-12-01    Kandy    Finance   59500.0
# 3         64886         Ruwan Perera 2019-12-01  Colombo    Finance   77600.0
# 10        26023  Dinusha Karunaratne 2016-12-01    Galle    Finance  143600.0
# 14        10769  Dinusha Karunaratne 2021-11-01   Jaffna    Finance       NaN
# 18        77969    Ishara Rathnayake 2018-06-01    Kandy    Finance  143000.0
# 25        35658       Thilini Perera 2021-03-01  Colombo    Finance       NaN
# 30        75725       Tharushi Silva 2020-01-01    Galle    Finance   87800.0
# 36        41551    Malsha Rathnayake 2016-09-01    Galle    Finance       NaN
# 52        27159        Nuwan Bandara 2018-03-01    Kandy    Finance       NaN
# 60        87189   Sajith Gunawardena 2022-09-01  Colombo    Finance       NaN
# ...

# %%
high_salary  = df[df['Salary']>140000]
high_salary
# Out:
#     Employee_ID                  Name  Join_Date     City  Department  \
# 5         92386       Tharushi Perera 2021-07-01   Jaffna   Marketing
# 10        26023   Dinusha Karunaratne 2016-12-01    Galle     Finance
# 11        51090  Tharushi Gunawardena 2015-04-01  Colombo   Marketing
# 18        77969     Ishara Rathnayake 2018-06-01    Kandy     Finance
# 49        78148    Suresh Karunaratne 2025-09-01  Colombo  Operations
# 81        19268      Kasun Jayasinghe 2022-08-01  Colombo   Marketing
# 88        48044         Chamari Silva 2025-12-01    Kandy          HR
# 94        72592     Rashmi Rathnayake 2022-05-01    Galle          HR
#
#       Salary
# 5   144700.0
# 10  143600.0
# 11  147800.0
# 18  143000.0
# 49  147200.0
# 81  149500.0
# 88  141300.0
# 94  149600.0

# %% [markdown]
# Using Queries

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df.query("City == 'Jaffna'").head(10)
# Out:
#     Employee_ID                  Name  Join_Date    City  Department    Salary
# 0         25795     Nuwan Gunawardena 2022-04-01  Jaffna          HR   73200.0
# 4         16265      Ruwan Rathnayake 2019-06-01  Jaffna          IT       NaN
# 5         92386       Tharushi Perera 2021-07-01  Jaffna   Marketing  144700.0
# 6         47194  Nadeesha Gunawardena 2020-02-01  Jaffna          HR  138200.0
# 7         97498     Tharushi De Alwis 2022-10-01  Jaffna          HR   68000.0
# 8         54131          Nuwan Perera 2022-02-01  Jaffna          IT   61900.0
# 12        77221    Janith Karunaratne 2016-12-01  Jaffna  Operations  119400.0
# 14        10769   Dinusha Karunaratne 2021-11-01  Jaffna     Finance       NaN
# 15        69735      Nuwan Jayasinghe 2017-10-01  Jaffna  Operations       NaN
# 28        12747      Ruwan Rathnayake 2021-03-01  Jaffna          HR   85700.0

# %%
df.query("Salary > 140000")
# Out:
#     Employee_ID                  Name  Join_Date     City  Department  \
# 5         92386       Tharushi Perera 2021-07-01   Jaffna   Marketing
# 10        26023   Dinusha Karunaratne 2016-12-01    Galle     Finance
# 11        51090  Tharushi Gunawardena 2015-04-01  Colombo   Marketing
# 18        77969     Ishara Rathnayake 2018-06-01    Kandy     Finance
# 49        78148    Suresh Karunaratne 2025-09-01  Colombo  Operations
# 81        19268      Kasun Jayasinghe 2022-08-01  Colombo   Marketing
# 88        48044         Chamari Silva 2025-12-01    Kandy          HR
# 94        72592     Rashmi Rathnayake 2022-05-01    Galle          HR
#
#       Salary
# 5   144700.0
# 10  143600.0
# 11  147800.0
# 18  143000.0
# 49  147200.0
# 81  149500.0
# 88  141300.0
# 94  149600.0

# %% [markdown]
# ### Handling missing values

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Checking how many missing values there are

# %%
df.isna().sum()
# Out:
# Employee_ID     0
# Name            0
# Join_Date       0
# City            0
# Department      0
# Salary         20
# dtype: int64

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Summarizing function

# %%
salary = df["Salary"]

salary_sum = salary.sum()
salary_count = salary.count()
salary_median = salary.median() 
salary_min = salary.min() 
salary_max = salary.max() 
salary_mean = salary.mean() 
salary_var = salary.var() 
salary_std = salary.std() 
salary_q1 = salary.quantile([0.25,0.75])



print(f"Total salary: {salary_sum}")
print(f"Count getting salary: {salary_count}")
print(f"Median salary: {salary_median}")
# Out:
# Total salary: 7692600.0
# Count getting salary: 80
# Median salary: 88750.0

# %%
salary = df["Salary"]


salary_quantiles = salary.quantile([0.25, 0.5, 0.75]) 
salary_quantiles
# Out:
# 0.25     69875.0
# 0.50     88750.0
# 0.75    122975.0
# Name: Salary, dtype: float64

# %% [markdown]
# Fill missing value with zero

# %%
df_1 = df_0 

# We can use inplace to overwrite the data frame, but this can sometimes be risky
df_1.fillna({'Salary':0}, inplace=True)
df_1
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena   4/1/2022   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne   4/1/2024  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe  12/1/2021    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera  12/1/2019  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake   6/1/2019   Jaffna          IT       0.0
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis   2/1/2017    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis   9/1/2022    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando   5/1/2019    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake   1/1/2021    Kandy          HR       0.0
# 99        97538      Malsha Bandara  10/1/2025    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Fill missing value using median

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT       NaN
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR       NaN
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df["Salary"].fillna(df["Salary"].median())
# Out:
# 0      73200.0
# 1      59800.0
# 2      59500.0
# 3      77600.0
# 4      88750.0
#         ...
# 95     71400.0
# 96     73900.0
# 97     79700.0
# 98     88750.0
# 99    134600.0
# Name: Salary, Length: 100, dtype: float64

# %%
df["Salary"]  = df["Salary"].fillna(df["Salary"].median())
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT   88750.0
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR   88750.0
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     Employee_ID                Name  Join_Date     City  Department    Salary
# 0         25795   Nuwan Gunawardena 2022-04-01   Jaffna          HR   73200.0
# 1         10860  Rashmi Karunaratne 2024-04-01  Colombo     Finance   59800.0
# 2         86820    Nuwan Jayasinghe 2021-12-01    Kandy     Finance   59500.0
# 3         64886        Ruwan Perera 2019-12-01  Colombo     Finance   77600.0
# 4         16265    Ruwan Rathnayake 2019-06-01   Jaffna          IT   88750.0
# ..          ...                 ...        ...      ...         ...       ...
# 95        77563    Thilini De Alwis 2017-02-01    Kandy          HR   71400.0
# 96        12695      Kasun De Alwis 2022-09-01    Galle   Marketing   73900.0
# 97        58190     Suresh Fernando 2019-05-01    Galle  Operations   79700.0
# 98        15258   Rashmi Rathnayake 2021-01-01    Kandy          HR   88750.0
# 99        97538      Malsha Bandara 2025-10-01    Kandy  Operations  134600.0
#
# [100 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  100 non-null    int64
#  1   Name         100 non-null    object
#  2   Join_Date    100 non-null    datetime64[ns]
#  3   City         100 non-null    object
#  4   Department   100 non-null    object
#  5   Salary       100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# Export dataset

# %%
df.to_csv("SL_employees_cleaned_stepwise.csv")
